# %%
import pandas as pd
import numpy as np
from csv import reader
from math import sqrt

# %%
df=pd.read_csv('car data1.csv')
test=pd.read_csv('car data test.csv')

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  no_years Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000         7    Petrol      Dealer
# 1           4.75           9.54       43000         8    Diesel      Dealer
# 2           7.25           9.85        6900         4    Petrol      Dealer
# 3           2.85           4.15        5200        10    Petrol      Dealer
# 4           4.60           6.87       42450         7    Diesel      Dealer
#
#   Transmission  Owner Car_Name  Year
# 0       Manual      0     ritz  2014
# 1       Manual      0      sx4  2013
# 2       Manual      0     ciaz  2017
# 3       Manual      0  wagon r  2011
# 4       Manual      0    swift  2014

# %%
test.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  no_years Fuel_Type Seller_Type  \
# 0           0.12           0.58       53000        14    Petrol  Individual
# 1           0.10           0.75       92233        15    Petrol  Individual
# 2           3.25           6.79       58000        11    Diesel      Dealer
# 3           4.40           5.70       28200         6    Petrol      Dealer
# 4           2.95           4.60       53460        10    Petrol      Dealer
#
#   Transmission  Owner          Car_Name  Year
# 0       Manual      0    Honda CB Shine  2007
# 1       Manual      0  Bajaj Pulsar 150  2006
# 2       Manual      1               i20  2010
# 3       Manual      0         grand i10  2015
# 4       Manual      0               i10  2011

# %%
df.shape
# Out:
# (301, 10)

# %%
test.shape
# Out:
# (102, 10)

# %%
print(df['Seller_Type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
print(test['Seller_Type'].unique())
print(test['Fuel_Type'].unique())
print(test['Transmission'].unique())
print(test['Owner'].unique())
# Out:
# ['Individual' 'Dealer']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1]

# %%
##check missing values
df.isnull().sum()
# Out:
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# no_years         0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# Car_Name         0
# Year             0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# no_years         0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# Car_Name         0
# Year             0
# dtype: int64

# %%
df.describe()
# Out:
#        Selling_Price  Present_Price     Kms_Driven    no_years       Owner  \
# count     301.000000     301.000000     301.000000  301.000000  301.000000
# mean        4.661296       7.628472   36947.205980    7.372093    0.043189
# std         5.082812       8.644115   38886.883882    2.891554    0.247915
# min         0.100000       0.320000     500.000000    3.000000    0.000000
# 25%         0.900000       1.200000   15000.000000    5.000000    0.000000
# 50%         3.600000       6.400000   32000.000000    7.000000    0.000000
# 75%         6.000000       9.900000   48767.000000    9.000000    0.000000
# max        35.000000      92.600000  500000.000000   18.000000    3.000000
#
#               Year
# count   301.000000
# mean   2013.627907
# std       2.891554
# min    2003.000000
# 25%    2012.000000
# 50%    2014.000000
# 75%    2016.000000
# max    2018.000000

# %%
df.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'no_years', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Car_Name', 'Year'],
#       dtype='object')

# %%
final_dataset=df[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]

# %%
test_dataset=test[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_dataset['Current Year']=2021

# %%
test_dataset['Current Year']=2021
# Out:
# C:\Users\nandini\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  no_year
# 0       Manual      0          2021        7
# 1       Manual      0          2021        8
# 2       Manual      0          2021        4
# 3       Manual      0          2021       10
# 4       Manual      0          2021        7

# %%
final_dataset['no_year']=final_dataset['Current Year']- final_dataset['Year']

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  no_year
# 0       Manual      0          2021        7
# 1       Manual      0          2021        8
# 2       Manual      0          2021        4
# 3       Manual      0          2021       10
# 4       Manual      0          2021        7

# %%
test_dataset['no_year']=test_dataset['Current Year']- test_dataset['Year']

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  no_year
# 0       Manual      0          2021        7
# 1       Manual      0          2021        8
# 2       Manual      0          2021        4
# 3       Manual      0          2021       10
# 4       Manual      0          2021        7

# %%
test_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2007           0.12           0.58       53000    Petrol  Individual
# 1  2006           0.10           0.75       92233    Petrol  Individual
# 2  2010           3.25           6.79       58000    Diesel      Dealer
# 3  2015           4.40           5.70       28200    Petrol      Dealer
# 4  2011           2.95           4.60       53460    Petrol      Dealer
#
#   Transmission  Owner  Current Year  no_year
# 0       Manual      0          2021       14
# 1       Manual      0          2021       15
# 2       Manual      1          2021       11
# 3       Manual      0          2021        6
# 4       Manual      0          2021       10

# %%
final_dataset=pd.get_dummies(final_dataset,drop_first=True)

# %%
test_dataset=pd.get_dummies(test_dataset,drop_first=True)

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Current Year  \
# 0  2014           3.35           5.59       27000      0          2021
# 1  2013           4.75           9.54       43000      0          2021
# 2  2017           7.25           9.85        6900      0          2021
# 3  2011           2.85           4.15        5200      0          2021
# 4  2014           4.60           6.87       42450      0          2021
#
#    no_year  Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0        7                 0                 1                       0
# 1        8                 1                 0                       0
# 2        4                 0                 1                       0
# 3       10                 0                 1                       0
# 4        7                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# ...

# %%
test_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Current Year  \
# 0  2007           0.12           0.58       53000      0          2021
# 1  2006           0.10           0.75       92233      0          2021
# 2  2010           3.25           6.79       58000      1          2021
# 3  2015           4.40           5.70       28200      0          2021
# 4  2011           2.95           4.60       53460      0          2021
#
#    no_year  Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0       14                 0                 1                       1
# 1       15                 0                 1                       1
# 2       11                 1                 0                       0
# 3        6                 0                 1                       0
# 4       10                 0                 1                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# ...

# %%
final_dataset=final_dataset.drop(['Current Year'],axis=1)

# %%
test_dataset=test_dataset.drop(['Current Year'],axis=1)

# %%
final_dataset.corr()
# Out:
#                             Year  Selling_Price  Present_Price  Kms_Driven  \
# Year                    1.000000       0.236141      -0.047584   -0.524342
# Selling_Price           0.236141       1.000000       0.878983    0.029187
# Present_Price          -0.047584       0.878983       1.000000    0.203647
# Kms_Driven             -0.524342       0.029187       0.203647    1.000000
# Owner                  -0.182104      -0.088344       0.008057    0.089216
# no_year                -1.000000      -0.236141       0.047584    0.524342
# Fuel_Type_Diesel        0.064315       0.552339       0.473306    0.172515
# Fuel_Type_Petrol       -0.059959      -0.540571      -0.465244   -0.172874
# Seller_Type_Individual -0.039896      -0.550724      -0.512030   -0.101419
# Transmission_Manual     0.000394      -0.367128      -0.348715   -0.162510
#
#                            Owner   no_year  Fuel_Type_Diesel  \
# Year                   -0.182104 -1.000000          0.064315
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  no_year  \
# 0    2014           3.35           5.59       27000      0        7
# 1    2013           4.75           9.54       43000      0        8
# 2    2017           7.25           9.85        6900      0        4
# 3    2011           2.85           4.15        5200      0       10
# 4    2014           4.60           6.87       42450      0        7
# ..    ...            ...            ...         ...    ...      ...
# 296  2016           9.50          11.60       33988      0        5
# 297  2015           4.00           5.90       60000      0        6
# 298  2009           3.35          11.00       87934      0       12
# 299  2017          11.50          12.50        9000      0        4
# 300  2016           5.30           5.90        5464      0        5
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# ...

# %%
final_dataset.drop(['Year'],axis=1,inplace=True)

# %%
test_dataset.drop(['Year'],axis=1,inplace=True)

# %%
X=final_dataset.iloc[:,1:]
y=final_dataset.iloc[:,0]

# %%
X_test=test_dataset.iloc[:,1:]
y_test=test_dataset.iloc[:,0]

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_Diesel  \
# 0           5.59       27000      0        7                 0
# 1           9.54       43000      0        8                 1
# 2           9.85        6900      0        4                 0
# 3           4.15        5200      0       10                 0
# 4           6.87       42450      0        7                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
#normalisation
my_data=final_dataset
my_data = (my_data - my_data.mean())/my_data.std()
my_data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven    Owner   no_year  \
# 0      -0.257986      -0.235822   -0.255798 -0.17421 -0.128683
# 1       0.017452       0.221136    0.155651 -0.17421  0.217152
# 2       0.509306       0.256999   -0.772682 -0.17421 -1.166187
# 3      -0.356357      -0.402409   -0.816399 -0.17421  0.908822
# 4      -0.012059      -0.087744    0.141508 -0.17421 -0.128683
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0         -0.498132           0.50848                -0.73606
# 1          2.000830          -1.96011                -0.73606
# 2         -0.498132           0.50848                -0.73606
# 3         -0.498132           0.50848                -0.73606
# 4          2.000830          -1.96011                -0.73606
#
#    Transmission_Manual
# 0             0.390829
# 1             0.390829
# 2             0.390829
# 3             0.390829
# 4             0.390829

# %%
test_data=test_dataset
test_data = (test_data - test_data.mean())/test_data.std()
test_data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven     Owner   no_year  \
# 0      -2.122076      -2.468993    0.936739 -0.173222  2.991785
# 1      -2.129633      -2.415278    2.919706 -0.173222  3.414447
# 2      -0.939383      -0.506822    1.189456  5.716334  1.723798
# 3      -0.504847      -0.851228   -0.316736 -0.173222 -0.389512
# 4      -1.052740      -1.198795    0.959989 -0.173222  1.301136
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0         -0.491438          0.521827                7.036320
# 1         -0.491438          0.521827                7.036320
# 2          2.014896         -1.897554               -0.140726
# 3         -0.491438          0.521827               -0.140726
# 4         -0.491438          0.521827               -0.140726
#
#    Transmission_Manual
# 0             0.290296
# 1             0.290296
# 2             0.290296
# 3             0.290296
# 4             0.290296

# %%
#setting the matrixes
X = my_data.iloc[:,1:]
ones = np.ones([X.shape[0],1])
X = np.concatenate((ones,X),axis=1)

y = my_data.iloc[:,0:1].values #.values converts it from pandas.core.frame.DataFrame to numpy.ndarray
theta = np.zeros([1,9])

#set hyper parameters
alpha = 0.01
iters = 1000

# %%
my_data1 = np.genfromtxt('Car data1.csv', delimiter=',')

# %%
y1 = my_data1[:, 1].reshape(-1,1)
plt.scatter(my_data1[:,0].reshape(-1,1),y1)

# %%
test_data1 = np.genfromtxt('Car data test.csv', delimiter=',')

# %%
ytest = test_data1[:, 1].reshape(-1,1)
plt.scatter(test_data1[:,0].reshape(-1,1),ytest)
plt.scatter(test_data1[1:,0].reshape(-1,1),y_prediction)

# %%
#setting the matrixes
X_test = test_data.iloc[:,1:]
ones = np.ones([X_test.shape[0],1])
X_test = np.concatenate((ones,X_test),axis=1)

y_test = test_data.iloc[:,0:1].values

# %%
#computecost
def computeCost(X,y,theta):
    tobesummed = np.power(((X @ theta.T)-y),2)
    return np.sum(tobesummed)/(2 * len(X))

# %%
#gradient descent
def gradientDescent(X,y,theta,iters,alpha):
    cost = np.zeros(iters)
    for i in range(iters):
        theta = theta - (alpha/len(X)) * np.sum(X * (X @ theta.T - y), axis=0)
        cost[i] = computeCost(X, y, theta)
    
    return theta,cost

#running the gd and cost function
g,cost = gradientDescent(X,y,theta,iters,alpha)
print("Optimal parameters",g)
print("The Initial cost is:",cost[0])

finalCost = computeCost(X,y,g)
print("The final cost is:",finalCost)
# Out:
# Optimal parameters [[-6.00295008e-16  7.36476198e-01 -5.56874911e-02 -3.21294109e-02
#   -2.21555810e-01  1.01492550e-01 -4.69532394e-02 -1.09730956e-01
#   -1.01430971e-01]]
# The Initial cost is: 0.479970558684913
# The final cost is: 0.05872215079834469

# %%
#plot the cost
fig, ax = plt.subplots()  
ax.plot(np.arange(iters), cost, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Error vs. Training Epoch')
# Out:
# Text(0.5, 1.0, 'Error vs. Training Epoch')

# %%
y_pred=X_test@g.T

# %%
y_prediction=list()
for k in y_pred:
    a=(k*final_dataset["Selling_Price"].std()+final_dataset["Selling_Price"].mean())
    y_prediction.append(a)

# %%
y_prediction
# Out:
# [array([-12.63920719]),
#  array([-13.47538052]),
#  array([0.97376891]),
#  array([1.58218526]),
#  array([-1.98414471]),
#  array([0.07886732]),
#  array([1.44981054]),
#  array([4.45042711]),
#  array([3.39601819]),
#  array([5.72712024]),
#  array([3.55373423]),
#  array([-1.25516781]),
#  array([13.98470333]),
#  array([11.48130596]),
#  array([0.91884528]),
#  array([3.22720383]),
#  array([4.41758043]),
#  array([0.78061945]),
#  array([0.74485384]),
#  array([5.24108094]),
#  array([4.99640737]),
#  array([0.88479977]),
#  array([3.77333319]),
#  array([4.51666362]),
#  array([7.35414953]),
#  array([6.80036061]),
#  array([-1.54146662]),
#  array([1.63257185]),
#  array([-2.23586332]),
#  array([5.9459935]),
#  array([2.97146999]),
#  array([6.63655814]),
#  array([7.09928279]),
#  array([14.46085402]),
#  array([2.14578074]),
#  array([1.92135768]),
#  array([7.09727991]),
#  array([0.78993281]),
#  array([12.22717955]),
#  array([4.54818439]),
#  array([-1.28362318]),
# ...

# %%
def rmse_metric(actual, predicted):
	sum_error = 0.0
	for i in range(len(actual)):
		prediction_error = predicted[i] - actual[i]
		sum_error += (prediction_error ** 2)
	mean_error = sum_error / float(len(actual))
	return sqrt(mean_error)

# %%
rmse_metric(y_test, y_pred)
# Out:
# 0.4203928770941566

# %%
y_test1= test_dataset.iloc[:,0:1].values

# %%
per_a=0
count=0
y=0
for j in range(len(y_test1)):
    accur=y_pred[j]/y_test1[j]
    per_acc=accur*100
    per_a=per_a+per_acc
    count=count+1
    y=y+y_test1[j]
y_avg=y/count
accu=100-((rmse_metric(y_test,y_pred)/y_avg[0])*100)

print("Accuracy of the model:",accu)
# Out:
# Accuracy of the model: 92.67107515833663
